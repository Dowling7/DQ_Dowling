# %%
import numpy as np
import os,sys
import math
from sklearn.cluster import KMeans
from scipy import spatial
import scipy.stats as sp
import uproot


#--------------------------------------------------------------------------------------------------------------------------------------------

def getData(fname="", procName="Events"):
    file = uproot.open(fname)
    dq_dict = file[procName].arrays(library="np")
    dq_events = {
        "Hits":{
            "detID": dq_dict["hit_detID"],
            "edep": dq_dict["hit_edep"],
            "elmID": dq_dict["hit_elmID"],
            "hit_pos": dq_dict["hit_pos"]
        },
        "track":{
            "x": dq_dict["track_x_CAL"],
            "y": dq_dict["track_y_CAL"],
            "ID": dq_dict["eventID"],
            "pz": dq_dict["track_pz_st1"]
        },
        "st23": {
            "ntrack23": dq_dict["n_st23tracklets"],
            "px":   dq_dict["st23tracklet_px_st3"],
            "py":   dq_dict["st23tracklet_py_st3"],
            "pz":   dq_dict["st23tracklet_pz_st3"],
            "x":   dq_dict["st23tracklet_x_st3"],
            "y":   dq_dict["st23tracklet_y_st3"],
            "z":   dq_dict["st23tracklet_z_st3"],
            "Cal_x": dq_dict["st23tracklet_x_CAL"],
            "Cal_y": dq_dict["st23tracklet_y_CAL"]
        }
    }

    return dq_events
#--------------------------------------------------------------------------------------------------------------------------------------------

ntowersx=72
ntowersy=36
sizex=5.53 # in cm
sizey=5.53 # in cm
ecalx=[-200,200] #size in cm
ecaly=[-100,100]
binsx=ecalx[1]- ecalx[0]
binsy=ecaly[1]- ecaly[0]
sfc = 0.1146337964120158 #sampling fraction of emcal
emin=0.0005
det_z={41: 2130.27, 42: 2146.45, 43:2200.44 , 44:2216.62 , 45:2251.71 , 46: 2234.29}


#--------------------------------------------------------------------------------------------------------------------------------------------

def emcal_bytuple(dq_events):
    dq_hits = dq_events["Hits"]
    x_pos = []
    y_pos = []
    eve_energy = []
    for i in range(len(dq_events["Hits"]["edep"])):
        output = emcal_byevent(dq_hits, i)
        if len(output[0]) != 0:
            x_pos.append(output[0])
            y_pos.append(output[1])
            eve_energy.append(output[2])
        else:
            x_pos.append(np.array([]))
            y_pos.append(np.array([]))
            eve_energy.append(np.array([]))
            
    return x_pos, y_pos, eve_energy

#--------------------------------------------------------------------------------------------------------------------------------------------

def emcal_byevent(dq_hits, evtNum):
    raw_elmID = dq_hits["elmID"][evtNum]
    raw_edep = dq_hits["edep"][evtNum]
    
    emcal_mask = dq_hits["detID"][evtNum] == 100
    eng_mask = raw_edep[emcal_mask] >= emin
    
    elmID = raw_elmID[emcal_mask][eng_mask]#could also use dstack here to zip (elmID and edep)
    edep = raw_edep[emcal_mask][eng_mask]
    
    emcal_towerx = elmID // ntowersy
    emcal_towery = elmID % ntowersy
    emcal_x = ecalx[0] + emcal_towerx * sizex
    emcal_y = ecaly[0] + emcal_towery * sizey
    emcal_edep = edep / sfc
    
    return emcal_x, emcal_y, emcal_edep

#--------------------------------------------------------------------------------------------------------------------------------------------

def find_energy_seeds(x, y, energy, min_energy=1, seed_radius=50):
    high_energy_mask =energy >min_energy
    high_energy_points = np.column_stack((x[high_energy_mask], y[high_energy_mask], energy[high_energy_mask]))
    seeds = []
    indices = []
    for i, (x_val, y_val, energy_val) in enumerate(high_energy_points):
        distances = np.array(np.sqrt((high_energy_points[:, 0] - x_val)**2 + (high_energy_points[:, 1] - y_val)**2))
        distances[i] = seed_radius + 1
        points_within_radius_mask = distances < seed_radius
        points_within_radius = high_energy_points[points_within_radius_mask]
        if len(points_within_radius) == 0 or energy_val > np.max(points_within_radius[:, 2], initial=0):
            seeds.append([x_val, y_val])
            indices.append(np.where(high_energy_mask)[0][i])
            
    return np.array(seeds), indices
    
#--------------------------------------------------------------------------------------------------------------------------------------------
def multi_clusters(dq_events):
    (x, y, eng)=emcal_bytuple(dq_events)
    labels=[]
    seeds=[]
    labels_decrease=[]
    seed_labels = []
    kmeans_ctr = []
    for i in range(len(eng)):
        (seed, index)=find_energy_seeds(x[i], y[i], eng[i])
        seeds.append(seed)
        points=np.column_stack((x[i],y[i]))
        try:
            kmeans = KMeans(n_clusters=len(seed), init=seed , random_state=0, n_init=1).fit(points)#since center given to grow, n_init==1
            labels.append(kmeans.labels_)
            label_decr = label_clus_eng(kmeans.labels_, eng[i])
            labels_decrease.append(label_decr)
            seed_labels.append(kmeans.labels_[index])
        except:
            labels.append([])
            labels_decrease.append([])
            seed_labels.append([])
    return x, y, eng, labels, labels_decrease, seeds, seed_labels
#--------------------------------------------------------------------------------------------------------------------------------------------

def label_clus_eng(label, eng_eve):#return sorted labels by decreasing order of energy
    unique_labels = np.unique(label)
    cluster_energy = np.zeros(len(unique_labels), dtype=np.int64)
    for i in range(len(label)):
        cluster_energy[label[i]] += eng_eve[i]
    sorted_labels = unique_labels[np.argsort(cluster_energy)[::-1]]
    return sorted_labels

#--------------------------------------------------------------------------------------------------------------------------------------------

def h4_bytuple(dq_events):
    dq_hits = dq_events["Hits"]
    

    hits = np.squeeze(np.dstack((dq_hits["detID"], dq_hits["hit_pos"])), axis=0)

    h4x = []
    h4y = []

    for index, item in enumerate(hits):
        h4x_mask = (41 <= item[0]) & (item[0] <= 44)
        h4y_mask = (45 <= item[0]) & (item[0] <= 46)
        ID_pos = np.squeeze(np.dstack((hits[index][0],hits[index][1])), axis=0)
        h4x.append(ID_pos[h4x_mask])
        h4y.append(ID_pos[h4y_mask])
    return h4x, h4y

#--------------------------------------------------------------------------------------------------------------------------------------------
def gen_wew(x_eve, y_eve, eng_eve):
    eng_tot = np.sum(eng_eve)
    x_bar = np.dot(x_eve, eng_eve) / eng_tot
    y_bar = np.dot(y_eve, eng_eve) / eng_tot

    x_sq_eve = eng_eve * (x_eve - x_bar) ** 2
    y_sq_eve = eng_eve * (y_eve - y_bar) ** 2

    try:
        wew_x = np.sqrt(np.sum(x_sq_eve) / eng_tot)
    except ZeroDivisionError:
        wew_x = -1

    try:
        wew_y = np.sqrt(np.sum(y_sq_eve) / eng_tot)
    except ZeroDivisionError:
        wew_y = -1

    return [wew_x, wew_y]
#--------------------------------------------------------------------------------------------------------------------------------------------
def gen_wid(x_eve, y_eve):
    x_bar = np.mean(x_eve)
    y_bar = np.mean(y_eve)

    x_sq_eve = (x_eve - x_bar) ** 2
    y_sq_eve = (y_eve - y_bar) ** 2

    try:
        wid_x = np.sqrt(np.mean(x_sq_eve))
    except ZeroDivisionError:
        wid_x = -1

    try:
        wid_y = np.sqrt(np.mean(y_sq_eve))
    except ZeroDivisionError:
        wid_y = -1

    return [wid_x, wid_y]
#--------------------------------------------------------------------------------------------------------------------------------------------

#--------------------------------------------------------------------------------------------------------------------------------------------

#--------------------------------------------------------------------------------------------------------------------------------------------

#--------------------------------------------------------------------------------------------------------------------------------------------

#--------------------------------------------------------------------------------------------------------------------------------------------

#--------------------------------------------------------------------------------------------------------------------------------------------

#--------------------------------------------------------------------------------------------------------------------------------------------

#--------------------------------------------------------------------------------------------------------------------------------------------

#--------------------------------------------------------------------------------------------------------------------------------------------

#--------------------------------------------------------------------------------------------------------------------------------------------

#--------------------------------------------------------------------------------------------------------------------------------------------

#--------------------------------------------------------------------------------------------------------------------------------------------

#--------------------------------------------------------------------------------------------------------------------------------------------

#--------------------------------------------------------------------------------------------------------------------------------------------

#--------------------------------------------------------------------------------------------------------------------------------------------

#--------------------------------------------------------------------------------------------------------------------------------------------

# %%
#this function is gaining data for training
file1='/Users/wongdowling/Desktop/DQ_Dowling/ntuple_1000/electron_520_1000eve.root'
file2='/Users/wongdowling/Desktop/n-tuples/aprime_yongbin/Aee_test_eps9.root'
file3='/Users/wongdowling/Desktop/DQ_Dowling/ntuple_1000/muon_520_1000eve.root'
file4='/Users/wongdowling/Desktop/n-tuples/aprime_cmantill/Amm_1.85_56_1000.root'

# %%
def find_muon_seeds(x, y, energy, min_energy=0.2, seed_radius=30):
    high_energy_mask =energy >min_energy
    high_energy_points = np.column_stack((x[high_energy_mask], y[high_energy_mask], energy[high_energy_mask]))
    seeds = []
    indices = []
    for i, (x_val, y_val, energy_val) in enumerate(high_energy_points):
        distances = np.array(np.sqrt((high_energy_points[:, 0] - x_val)**2 + (high_energy_points[:, 1] - y_val)**2))
        distances[i] = seed_radius + 1
        points_within_radius_mask = distances < seed_radius
        points_within_radius = high_energy_points[points_within_radius_mask]
        if len(points_within_radius) == 0 or energy_val > np.max(points_within_radius[:, 2], initial=0):
            seeds.append([x_val, y_val])
            indices.append(np.where(high_energy_mask)[0][i])
            
    return np.array(seeds), indices

# %%
dq_events = getData(file1, "Events")
cal_x=dq_events["st23"]["Cal_x"]
(x, y, eng)=emcal_bytuple(dq_events)
labels=[]
seeds=[]
labels_decrease=[]
seed_labels = []
kmeans_ctr = []
n=0
for i in range(len(eng)):
    (seed, index)=find_muon_seeds(x[i], y[i], eng[i])
    seeds.append(seed)
    if len(seed)==1:
        n+=1
print(n)
# Out:
# 961

# %%
cal_x
# Out:
# array([array([-2.9032815], dtype=float32),
#        array([-9.814391], dtype=float32),
#        array([11.0173025], dtype=float32),
#        array([7.5012164], dtype=float32),
#        array([17.144585], dtype=float32),
#        array([-1.3583667], dtype=float32),
#        array([2.9516265], dtype=float32),
#        array([9.040945], dtype=float32), array([9.511023], dtype=float32),
#        array([15.5037775], dtype=float32),
#        array([12.162357], dtype=float32),
#        array([-2.267294], dtype=float32),
#        array([15.198478], dtype=float32),
#        array([-25.037766], dtype=float32),
#        array([-15.2611885], dtype=float32),
#        array([-1.0063428], dtype=float32),
#        array([2.1871042], dtype=float32),
#        array([9.325328], dtype=float32),
#        array([-14.126964], dtype=float32),
#        array([-2.6646216], dtype=float32),
#        array([1.0261719], dtype=float32),
#        array([6.0691094], dtype=float32),
#        array([-27.068176], dtype=float32),
#        array([-13.846477], dtype=float32),
#        array([1.4802045], dtype=float32),
#        array([11.156494], dtype=float32),
#        array([7.161367], dtype=float32),
#        array([9.7610235], dtype=float32),
#        array([-5.2120914], dtype=float32),
#        array([4.0917807], dtype=float32),
#        array([1.3345556], dtype=float32),
#        array([-21.403093], dtype=float32),
#        array([-23.461327], dtype=float32),
#        array([8.125012], dtype=float32), array([5.98891], dtype=float32),
#        array([16.313442], dtype=float32),
#        array([11.657391], dtype=float32),
#        array([-7.6537175], dtype=float32),
#        array([-3.3621552], dtype=float32),
#        array([2.1170063], dtype=float32),
#        array([-2.756958], dtype=float32),
#        array([2.8306482], dtype=float32),
#        array([-2.0306327], dtype=float32),
#        array([-14.727819], dtype=float32),
#        array([-4.745669], dtype=float32),
#        array([-2.5614393], dtype=float32),
#        array([-7.9696665], dtype=float32),
#        array([-12.929328], dtype=float32),
#        array([12.078171], dtype=float32),
#        array([3.7353258, 8.678068 ], dtype=float32),
#        array([-0.5681443], dtype=float32),
#        array([-12.16688], dtype=float32),
#        array([-1.8389399], dtype=float32),
#        array([16.852707], dtype=float32),
#        array([-0.30920509], dtype=float32),
#        array([2.8874433], dtype=float32),
#        array([8.953342], dtype=float32),
#        array([-0.3344679], dtype=float32),
#        array([-3.442172], dtype=float32),
#        array([3.6341288], dtype=float32),
#        array([9.145675], dtype=float32),
#        array([14.918932], dtype=float32),
#        array([-6.344173], dtype=float32),
#        array([1.8283337], dtype=float32),
#        array([8.694541], dtype=float32),
#        array([-5.479867], dtype=float32),
#        array([-6.152608], dtype=float32),
#        array([-6.4826384], dtype=float32),
#        array([3.0062246], dtype=float32),
#        array([-7.3443108], dtype=float32),
#        array([1.8406668], dtype=float32),
#        array([-7.209222], dtype=float32),
#        array([4.2803073], dtype=float32),
#        array([4.058677], dtype=float32),
#        array([3.3050764], dtype=float32),
#        array([-10.485141], dtype=float32),
#        array([-3.7852585], dtype=float32),
#        array([-3.5944626], dtype=float32),
#        array([6.8089757], dtype=float32),
#        array([6.244129], dtype=float32),
#        array([-18.47587], dtype=float32),
#        array([-15.408208], dtype=float32),
#        array([-17.481653], dtype=float32),
#        array([-25.020979], dtype=float32),
#        array([2.8378034, 9.855367 ], dtype=float32),
#        array([-1.9216641], dtype=float32),
#        array([-2.9762137], dtype=float32),
#        array([-5.2977448], dtype=float32),
#        array([-18.616499], dtype=float32),
#        array([-3.9186556, -0.2957702], dtype=float32),
#        array([-4.495241], dtype=float32),
#        array([9.990767], dtype=float32),
#        array([-36.077835], dtype=float32),
#        array([-5.4008093], dtype=float32),
#        array([4.279061], dtype=float32),
#        array([-5.0642314], dtype=float32),
#        array([10.61264], dtype=float32),
#        array([ 7.7158885, 20.655521 ,  6.4135   ], dtype=float32),
#        array([], dtype=float32), array([6.885626], dtype=float32),
#        array([], dtype=float32), array([1.0252964], dtype=float32),
#        array([9.583361], dtype=float32), array([6.328333], dtype=float32),
#        array([-30.23607], dtype=float32),
#        array([-3.0506763], dtype=float32),
#        array([-2.8634639], dtype=float32),
#        array([-2.8356626], dtype=float32),
#        array([-6.315281], dtype=float32),
#        array([-7.903018], dtype=float32),
#        array([-35.9633], dtype=float32),
#        array([-3.6621013], dtype=float32),
#        array([-10.691296], dtype=float32),
#        array([-3.696543], dtype=float32),
#        array([6.201791], dtype=float32),
#        array([6.4617248], dtype=float32),
#        array([ -2.4565659, -24.80546  ], dtype=float32),
#        array([-14.190409], dtype=float32),
#        array([-58.635303], dtype=float32),
#        array([-3.830804], dtype=float32),
#        array([-4.8012004], dtype=float32),
#        array([-4.7859607], dtype=float32),
#        array([5.853613], dtype=float32),
#        array([14.489698], dtype=float32),
#        array([ 3.668195,  9.831634, 16.897774], dtype=float32),
#        array([8.379205], dtype=float32),
#        array([10.092498], dtype=float32),
#        array([3.7597547], dtype=float32),
#        array([6.5999312], dtype=float32),
#        array([-0.7351577], dtype=float32),
#        array([1.9944077], dtype=float32),
#        array([-0.5455569], dtype=float32),
#        array([-3.8894212], dtype=float32),
#        array([9.080605], dtype=float32),
#        array([-10.686737 , -17.257929 ,   6.5426555], dtype=float32),
#        array([3.9398644], dtype=float32),
#        array([-8.030027], dtype=float32), array([2.96825], dtype=float32),
#        array([3.0399594], dtype=float32),
#        array([-3.0602367], dtype=float32),
#        array([8.783787], dtype=float32),
#        array([-1.3053309], dtype=float32),
#        array([1.3544382], dtype=float32),
#        array([10.226489], dtype=float32),
#        array([-8.6328745], dtype=float32),
#        array([4.7291427], dtype=float32),
#        array([3.8671644], dtype=float32),
#        array([8.481711], dtype=float32), array([6.327784], dtype=float32),
#        array([-4.9361873], dtype=float32),
#        array([-0.59875876], dtype=float32),
#        array([2.9307933], dtype=float32),
#        array([-6.1449904], dtype=float32),
#        array([-6.1757617], dtype=float32),
#        array([0.02994305], dtype=float32),
#        array([-4.512834], dtype=float32),
#        array([9.986424], dtype=float32),
#        array([-5.5331273], dtype=float32),
#        array([2.1922452], dtype=float32),
#        array([-2.5237534], dtype=float32),
#        array([-8.603688], dtype=float32),
#        array([11.117846], dtype=float32),
#        array([5.3619423], dtype=float32),
#        array([-5.650702], dtype=float32),
#        array([0.3561355], dtype=float32),
#        array([5.9271817], dtype=float32),
#        array([-7.480553], dtype=float32),
#        array([8.4480715], dtype=float32),
#        array([1.645375], dtype=float32),
#        array([-8.438034], dtype=float32),
#        array([-6.041844], dtype=float32),
#        array([4.9802237], dtype=float32),
#        array([-2.5011625], dtype=float32),
#        array([11.254895], dtype=float32),
#        array([4.824759], dtype=float32),
#        array([-14.318848], dtype=float32),
#        array([-10.685185], dtype=float32),
#        array([-1.5295042], dtype=float32),
#        array([9.363661 , 1.0014923], dtype=float32),
#        array([-2.784861], dtype=float32),
#        array([10.720954], dtype=float32),
#        array([-2.9173262], dtype=float32),
#        array([-1.3703512], dtype=float32),
#        array([9.549348], dtype=float32),
#        array([-5.1178484], dtype=float32),
#        array([6.360606], dtype=float32),
#        array([ -1.6962363, -10.732904 ], dtype=float32),
#        array([4.4222193], dtype=float32),
#        array([  2.9498842, -53.695164 ], dtype=float32),
#        array([2.3583517], dtype=float32),
#        array([2.7117047], dtype=float32),
#        array([0.85279846], dtype=float32),
#        array([-10.214047], dtype=float32),
#        array([-0.33305043], dtype=float32),
#        array([5.25118], dtype=float32), array([11.197884], dtype=float32),
#        array([ 6.621692 , 49.18151  ,  5.8584657, 50.100502 ], dtype=float32),
#        array([4.520031], dtype=float32), array([], dtype=float32),
#        array([-7.1687446], dtype=float32),
#        array([6.9695873], dtype=float32),
#        array([2.4395585], dtype=float32),
#        array([17.19215], dtype=float32),
#        array([-9.144183], dtype=float32),
#        array([-19.94628], dtype=float32),
#        array([-13.24948], dtype=float32),
#        array([9.108973], dtype=float32),
#        array([0.55190974], dtype=float32),
#        array([-7.9675746], dtype=float32),
#        array([8.033935], dtype=float32),
#        array([-10.724844], dtype=float32),
#        array([-1.321832], dtype=float32),
#        array([-4.1069093], dtype=float32),
#        array([0.36188138], dtype=float32),
#        array([8.258511], dtype=float32),
#        array([-8.818801], dtype=float32),
#        array([-19.92958], dtype=float32),
#        array([-6.9720526], dtype=float32),
#        array([-1.2555269], dtype=float32),
#        array([14.5096445], dtype=float32),
#        array([9.387965], dtype=float32),
#        array([11.554629], dtype=float32),
#        array([11.142554, 12.238542], dtype=float32),
#        array([-0.978331], dtype=float32),
#        array([-5.3617096], dtype=float32),
#        array([-2.417033], dtype=float32),
#        array([4.4153233], dtype=float32),
#        array([10.25457], dtype=float32),
#        array([  6.2807956, -14.269955 ,   6.0762353], dtype=float32),
#        array([3.5363007], dtype=float32),
#        array([4.3267994], dtype=float32),
#        array([-9.878681], dtype=float32),
#        array([-2.930631], dtype=float32),
#        array([5.6901793], dtype=float32),
#        array([-3.1507094], dtype=float32),
#        array([-3.7698777], dtype=float32),
#        array([14.076271], dtype=float32),
#        array([5.5224423], dtype=float32),
#        array([-8.335291], dtype=float32),
#        array([-4.1754613], dtype=float32), array([], dtype=float32),
#        array([ 9.59332, 40.64478], dtype=float32),
#        array([9.764419], dtype=float32), array([4.561971], dtype=float32),
#        array([1.7479216], dtype=float32),
#        array([ -4.3245034, -63.42226  ,  -2.320505 ], dtype=float32),
#        array([0.97608817], dtype=float32),
#        array([4.2780666], dtype=float32), array([8.01704], dtype=float32),
#        array([-0.15132907], dtype=float32),
#        array([0.07536606], dtype=float32),
#        array([4.640665], dtype=float32),
#        array([-0.9732705], dtype=float32),
#        array([15.491547], dtype=float32),
#        array([4.513867], dtype=float32),
#        array([10.618229], dtype=float32),
#        array([-17.18955], dtype=float32),
#        array([13.464509], dtype=float32),
#        array([-1.6710498], dtype=float32),
#        array([10.680018], dtype=float32),
#        array([1.8234442], dtype=float32),
#        array([-0.871174], dtype=float32),
#        array([-0.84483534], dtype=float32),
#        array([-6.4227986], dtype=float32),
#        array([2.8422692], dtype=float32),
#        array([-0.08696079], dtype=float32),
#        array([-1.6065257], dtype=float32),
#        array([-29.741564], dtype=float32),
#        array([-8.433527], dtype=float32),
#        array([5.387377], dtype=float32),
#        array([3.9684875], dtype=float32),
#        array([0.18466963], dtype=float32),
#        array([-2.744163], dtype=float32),
#        array([-27.68785 , -44.22393 , -27.392689, -43.802177], dtype=float32),
#        array([-4.2336082], dtype=float32),
#        array([2.652227], dtype=float32),
#        array([-3.0225828], dtype=float32),
#        array([8.511549], dtype=float32), array([], dtype=float32),
#        array([11.014709], dtype=float32),
#        array([9.4286375], dtype=float32),
#        array([ -9.870075, -38.359432, -37.7218  ,  -9.194336], dtype=float32),
#        array([7.3709073], dtype=float32),
#        array([0.27986485], dtype=float32),
#        array([-0.61486006], dtype=float32),
#        array([-19.233047], dtype=float32),
#        array([0.9390706], dtype=float32),
#        array([-7.6300526], dtype=float32),
#        array([4.7445493], dtype=float32),
#        array([5.521496], dtype=float32),
#        array([-0.6503846], dtype=float32),
#        array([15.023131], dtype=float32),
#        array([-4.9657736], dtype=float32),
#        array([9.6860075], dtype=float32),
#        array([11.362392, 18.689583], dtype=float32),
#        array([-2.5582318], dtype=float32),
#        array([5.1975293], dtype=float32),
#        array([-31.464066], dtype=float32),
#        array([1.8040714], dtype=float32),
#        array([16.410212], dtype=float32),
#        array([-25.24758], dtype=float32),
#        array([4.5229306], dtype=float32),
#        array([-0.11429848], dtype=float32),
#        array([-4.193936], dtype=float32),
#        array([-5.1740212], dtype=float32),
#        array([9.014254], dtype=float32),
#        array([4.4864726, 0.5158006], dtype=float32),
#        array([-2.9735122], dtype=float32),
#        array([1.1127961], dtype=float32),
#        array([-4.1473227], dtype=float32),
#        array([-6.288899], dtype=float32),
#        array([-0.93249243], dtype=float32),
#        array([-2.0110278], dtype=float32),
#        array([2.3559732, 5.838603 ], dtype=float32),
#        array([-3.6561277], dtype=float32),
#        array([-12.589895], dtype=float32),
#        array([0.7531198], dtype=float32),
#        array([0.51843464], dtype=float32),
#        array([4.9027033], dtype=float32),
#        array([2.7153146], dtype=float32),
#        array([3.222329], dtype=float32), array([2.429515], dtype=float32),
#        array([-1.7398667], dtype=float32),
#        array([14.944276], dtype=float32),
#        array([-11.594789], dtype=float32),
#        array([14.7730465], dtype=float32),
#        array([0.02351448], dtype=float32),
#        array([-17.444252], dtype=float32),
#        array([-5.794338], dtype=float32),
#        array([-6.646271], dtype=float32),
#        array([3.0957682], dtype=float32),
#        array([-6.0645614], dtype=float32),
#        array([10.237914], dtype=float32),
#        array([15.3818035], dtype=float32),
#        array([5.089252], dtype=float32),
#        array([-3.4792852], dtype=float32),
#        array([8.806405], dtype=float32),
#        array([2.5396507], dtype=float32),
#        array([12.973889], dtype=float32),
#        array([11.852692], dtype=float32),
#        array([5.2462497], dtype=float32),
#        array([14.084693], dtype=float32),
#        array([7.558294], dtype=float32),
#        array([2.1500037], dtype=float32),
#        array([-5.384935], dtype=float32),
#        array([10.190683], dtype=float32),
#        array([-18.906248], dtype=float32),
#        array([-11.604731], dtype=float32),
#        array([ 6.178642 , 13.9548435, 13.924259 , 18.816488 , 19.625242 ,
#                5.983661 ], dtype=float32)                                ,
#        array([-11.668735 ,   2.1306953], dtype=float32),
#        array([7.826725], dtype=float32),
#        array([-1.3442072], dtype=float32),
#        array([-10.546235], dtype=float32),
#        array([-2.430332], dtype=float32),
#        array([4.2003956], dtype=float32),
#        array([2.7686694], dtype=float32),
#        array([3.3309066], dtype=float32),
#        array([-4.6283345], dtype=float32),
#        array([0.3900994], dtype=float32),
#        array([-3.668325], dtype=float32), array([], dtype=float32),
#        array([13.998477], dtype=float32), array([4.84277], dtype=float32),
#        array([3.9274514], dtype=float32),
#        array([2.8975885], dtype=float32),
#        array([10.019506], dtype=float32),
#        array([14.210032], dtype=float32),
#        array([-2.4312747], dtype=float32),
#        array([5.239593], dtype=float32),
#        array([-5.135522], dtype=float32),
#        array([5.7310305], dtype=float32),
#        array([-5.094717], dtype=float32),
#        array([-3.818037], dtype=float32),
#        array([15.839018], dtype=float32),
#        array([-11.619658], dtype=float32),
#        array([1.0812196], dtype=float32),
#        array([-2.924867], dtype=float32),
#        array([10.683609], dtype=float32),
#        array([2.5797553], dtype=float32),
#        array([-20.282907], dtype=float32),
#        array([-1.2550247], dtype=float32),
#        array([-15.030423], dtype=float32),
#        array([5.767905], dtype=float32),
#        array([11.117548], dtype=float32),
#        array([-0.9363623], dtype=float32),
#        array([13.428565], dtype=float32),
#        array([3.1298513], dtype=float32),
#        array([-17.992525], dtype=float32),
#        array([2.1730287], dtype=float32),
#        array([-0.88169223], dtype=float32),
#        array([12.218092], dtype=float32),
#        array([6.304504], dtype=float32),
#        array([11.444353], dtype=float32),
#        array([2.9466949], dtype=float32),
#        array([12.913584], dtype=float32),
#        array([-15.549802], dtype=float32),
#        array([3.1798878], dtype=float32),
#        array([5.4816346], dtype=float32),
#        array([7.0250325], dtype=float32),
#        array([-12.348496], dtype=float32),
#        array([15.099178], dtype=float32),
#        array([-7.015495], dtype=float32),
#        array([6.327559], dtype=float32),
#        array([12.160719], dtype=float32),
#        array([1.8872371], dtype=float32),
#        array([-2.7260265], dtype=float32),
#        array([-1.8122104], dtype=float32),
#        array([-9.85166], dtype=float32),
#        array([-7.8326488], dtype=float32),
#        array([5.1437473], dtype=float32),
#        array([-10.5027895], dtype=float32),
#        array([-5.021674], dtype=float32),
#        array([-5.7968783], dtype=float32),
#        array([-1.3966155], dtype=float32),
#        array([4.680809], dtype=float32),
#        array([7.1764984], dtype=float32),
#        array([0.21245886], dtype=float32),
#        array([9.322328], dtype=float32),
#        array([4.4371033], dtype=float32),
#        array([-1.4256936], dtype=float32),
#        array([10.762141], dtype=float32), array([8.19013], dtype=float32),
#        array([-1.7999468], dtype=float32),
#        array([6.6214757], dtype=float32),
#        array([13.666737], dtype=float32),
#        array([3.4621923], dtype=float32),
#        array([-5.0482063], dtype=float32),
#        array([-8.882149], dtype=float32),
#        array([-4.8988037], dtype=float32),
#        array([5.766493], dtype=float32), array([5.401828], dtype=float32),
#        array([5.757115], dtype=float32),
#        array([-5.682035], dtype=float32),
#        array([-5.1577854], dtype=float32),
#        array([-0.8603435], dtype=float32),
#        array([-4.2776976], dtype=float32),
#        array([4.604989], dtype=float32), array([5.034996], dtype=float32),
#        array([-7.203412], dtype=float32),
#        array([0.80641776], dtype=float32),
#        array([-25.25137], dtype=float32),
#        array([-0.0698608], dtype=float32),
#        array([11.150822], dtype=float32),
#        array([1.7828145], dtype=float32),
#        array([2.821814], dtype=float32),
#        array([12.948257], dtype=float32),
#        array([8.921691], dtype=float32),
#        array([3.3960152], dtype=float32),
#        array([-4.375741], dtype=float32),
#        array([-4.039999], dtype=float32),
#        array([-4.325237], dtype=float32),
#        array([4.093298], dtype=float32),
#        array([-6.317541], dtype=float32),
#        array([12.132552], dtype=float32),
#        array([10.661002], dtype=float32),
#        array([4.5838823], dtype=float32),
#        array([2.5465715], dtype=float32),
#        array([4.564429], dtype=float32), array([8.419082], dtype=float32),
#        array([14.094845], dtype=float32), array([7.57153], dtype=float32),
#        array([4.410293], dtype=float32), array([-24.7863], dtype=float32),
#        array([4.7785115], dtype=float32),
#        array([-7.358379], dtype=float32),
#        array([-50.11203], dtype=float32),
#        array([-2.0644343], dtype=float32),
#        array([0.35224283], dtype=float32),
#        array([1.3642745], dtype=float32),
#        array([-5.778596], dtype=float32),
#        array([1.7923027], dtype=float32),
#        array([-1.7050116], dtype=float32),
#        array([-43.721027], dtype=float32),
#        array([-7.718061,  8.723263], dtype=float32),
#        array([17.784101], dtype=float32),
#        array([3.4148571], dtype=float32),
#        array([-11.054026], dtype=float32),
#        array([10.291877], dtype=float32),
#        array([2.4962966], dtype=float32),
#        array([-7.761546], dtype=float32),
#        array([-3.682685], dtype=float32),
#        array([9.314967], dtype=float32),
#        array([-2.417797], dtype=float32),
#        array([-0.45858842], dtype=float32),
#        array([7.3949275], dtype=float32),
#        array([4.6687036], dtype=float32),
#        array([0.5264844], dtype=float32),
#        array([9.250443], dtype=float32),
#        array([6.5865912], dtype=float32),
#        array([-5.181751], dtype=float32),
#        array([13.136053], dtype=float32),
#        array([9.584711], dtype=float32), array([-8.60419], dtype=float32),
#        array([-0.29809073], dtype=float32),
#        array([-19.232206], dtype=float32),
#        array([-5.633426], dtype=float32),
#        array([-5.4788523], dtype=float32),
#        array([-15.198359], dtype=float32),
#        array([8.211033], dtype=float32),
#        array([4.6025085], dtype=float32),
#        array([-0.14449413], dtype=float32),
#        array([16.478], dtype=float32), array([6.050501], dtype=float32),
#        array([-8.511517], dtype=float32),
#        array([-6.115085], dtype=float32),
#        array([-3.4323685], dtype=float32),
#        array([11.317587], dtype=float32),
#        array([-3.695626], dtype=float32),
#        array([-8.926597], dtype=float32),
#        array([1.7544801], dtype=float32),
#        array([-2.9837995], dtype=float32),
#        array([-5.816466], dtype=float32),
#        array([-8.13637  , -5.3090353, 25.000399 ], dtype=float32),
#        array([11.9479265], dtype=float32),
#        array([-28.738497], dtype=float32),
#        array([8.803029], dtype=float32), array([5.499288], dtype=float32),
#        array([-4.7794785], dtype=float32),
#        array([1.1747826], dtype=float32),
#        array([12.061737], dtype=float32),
#        array([-8.713357], dtype=float32),
#        array([5.914432], dtype=float32),
#        array([14.203988], dtype=float32),
#        array([-22.860683], dtype=float32),
#        array([12.591344], dtype=float32),
#        array([  0.70402616, 106.51349   ], dtype=float32),
#        array([-7.931219], dtype=float32),
#        array([-12.615955], dtype=float32),
#        array([-0.33289883], dtype=float32),
#        array([3.733955], dtype=float32),
#        array([0.9120378], dtype=float32),
#        array([16.020134], dtype=float32),
#        array([-2.684466], dtype=float32),
#        array([1.5843066], dtype=float32),
#        array([-1.2507917], dtype=float32),
#        array([6.4971347], dtype=float32),
#        array([-9.860699], dtype=float32),
#        array([7.518149], dtype=float32),
#        array([12.845725], dtype=float32),
#        array([-6.90943], dtype=float32), array([7.730252], dtype=float32),
#        array([13.040062], dtype=float32),
#        array([9.488308], dtype=float32),
#        array([10.450283], dtype=float32),
#        array([-0.2793747], dtype=float32),
#        array([-1.3188747], dtype=float32),
#        array([10.855227], dtype=float32),
#        array([7.1954875], dtype=float32),
#        array([14.078765, 32.49224 ], dtype=float32),
#        array([-0.04405047], dtype=float32),
#        array([-5.003193], dtype=float32),
#        array([ 5.4353247, 10.006333 ], dtype=float32),
#        array([6.269454], dtype=float32),
#        array([-5.309162], dtype=float32),
#        array([0.9314726], dtype=float32),
#        array([3.6338184], dtype=float32),
#        array([-3.1280298], dtype=float32),
#        array([7.094769], dtype=float32),
#        array([13.144351,  9.71882 ], dtype=float32),
#        array([3.4918149], dtype=float32),
#        array([9.697562], dtype=float32),
#        array([-10.62278], dtype=float32),
#        array([8.292029], dtype=float32),
#        array([ -3.6596653, -16.095478 ], dtype=float32),
#        array([-3.9251885], dtype=float32),
#        array([1.5918425], dtype=float32),
#        array([2.3635812], dtype=float32),
#        array([ 5.2818956, 16.60617  ], dtype=float32),
#        array([0.7916125], dtype=float32),
#        array([-35.39482], dtype=float32),
#        array([5.0309505], dtype=float32),
#        array([14.756814], dtype=float32),
#        array([15.283907], dtype=float32),
#        array([12.451576], dtype=float32),
#        array([-13.397282], dtype=float32),
#        array([-6.2792277], dtype=float32),
#        array([4.495483], dtype=float32),
#        array([0.45416293, 6.5910196 , 3.3949327 , 6.117368  , 0.13731341],
#              dtype=float32)                                               ,
#        array([7.9932437], dtype=float32),
#        array([-12.882086], dtype=float32),
#        array([-14.07345], dtype=float32),
#        array([3.1688786], dtype=float32),
#        array([-3.229642], dtype=float32),
#        array([-15.18323], dtype=float32),
#        array([-16.69149], dtype=float32), array([8.76794], dtype=float32),
#        array([], dtype=float32), array([-10.103341], dtype=float32),
#        array([-2.3428154], dtype=float32),
#        array([-7.534711], dtype=float32),
#        array([8.694738], dtype=float32),
#        array([-1.4452192], dtype=float32),
#        array([2.472819], dtype=float32), array([8.468227], dtype=float32),
#        array([6.4236493], dtype=float32),
#        array([4.349253], dtype=float32),
#        array([1.7152625], dtype=float32), array([8.65123], dtype=float32),
#        array([-6.7547655], dtype=float32),
#        array([-15.290506], dtype=float32),
#        array([-8.700824, -1.091307], dtype=float32),
#        array([-1.4650323], dtype=float32),
#        array([0.17301959], dtype=float32),
#        array([-0.26167876,  6.9508214 ], dtype=float32),
#        array([-9.128286], dtype=float32),
#        array([-2.6857984], dtype=float32),
#        array([3.5797055], dtype=float32),
#        array([3.463418], dtype=float32),
#        array([1.0745485], dtype=float32),
#        array([0.6641331], dtype=float32),
#        array([-0.83914036], dtype=float32),
#        array([3.8525572], dtype=float32),
#        array([-24.409208], dtype=float32),
#        array([-1.2038634], dtype=float32),
#        array([5.3994617], dtype=float32),
#        array([-7.02629], dtype=float32),
#        array([7.1849284], dtype=float32),
#        array([3.8586028], dtype=float32),
#        array([-6.7178273], dtype=float32),
#        array([10.166903], dtype=float32),
#        array([16.080961], dtype=float32),
#        array([8.564282], dtype=float32), array([4.000144], dtype=float32),
#        array([7.000173], dtype=float32), array([9.547377], dtype=float32),
#        array([-5.8782506], dtype=float32),
#        array([-2.4702592], dtype=float32),
#        array([-0.27589214], dtype=float32),
#        array([-4.390448 ,  3.1973257], dtype=float32),
#        array([-7.672115], dtype=float32),
#        array([15.312326], dtype=float32),
#        array([-1.8881148], dtype=float32),
#        array([11.93232], dtype=float32),
#        array([-11.947057], dtype=float32),
#        array([-10.147532], dtype=float32),
#        array([17.44007 , 37.520126, 38.03581 , 16.987772], dtype=float32),
#        array([10.521372], dtype=float32),
#        array([-13.054696], dtype=float32),
#        array([-1.98726], dtype=float32),
#        array([-10.856117], dtype=float32),
#        array([6.1572366], dtype=float32),
#        array([-3.137632], dtype=float32),
#        array([-10.932369, -44.96713 ], dtype=float32),
#        array([12.784714], dtype=float32),
#        array([-10.885687], dtype=float32),
#        array([-5.9036527, -0.4552029], dtype=float32),
#        array([0.4272782], dtype=float32),
#        array([13.20308], dtype=float32),
#        array([12.656652], dtype=float32),
#        array([  4.2485843, -17.524324 ], dtype=float32),
#        array([-1.022772], dtype=float32),
#        array([3.4749012], dtype=float32),
#        array([11.759566], dtype=float32),
#        array([9.511601], dtype=float32),
#        array([-1.1409457], dtype=float32),
#        array([-15.861793], dtype=float32),
#        array([8.5896635], dtype=float32), array([8.11557], dtype=float32),
#        array([0.28819317], dtype=float32),
#        array([3.5814784], dtype=float32),
#        array([-8.978329], dtype=float32),
#        array([-30.618252], dtype=float32),
#        array([6.9582586], dtype=float32),
#        array([-0.21932524], dtype=float32),
#        array([8.307429], dtype=float32),
#        array([-1.9058179], dtype=float32),
#        array([-8.860351], dtype=float32),
#        array([5.7394457], dtype=float32),
#        array([13.843509], dtype=float32),
#        array([-11.128756], dtype=float32),
#        array([-4.5882287], dtype=float32),
#        array([5.096894], dtype=float32),
#        array([14.358155, 20.794298,  7.889919], dtype=float32),
#        array([-8.826742], dtype=float32),
#        array([10.739678], dtype=float32),
#        array([-4.6268635], dtype=float32),
#        array([5.223902], dtype=float32),
#        array([0.45232594], dtype=float32),
#        array([4.692387], dtype=float32),
#        array([  7.38178 ,  15.842877, -18.171358], dtype=float32),
#        array([-4.8855677, 30.048428 , 31.252386 , -5.4244404], dtype=float32),
#        array([-0.2437954], dtype=float32),
#        array([-6.587429], dtype=float32),
#        array([16.474289], dtype=float32),
#        array([-2.9799714], dtype=float32),
#        array([-3.4695477, -1.7895023], dtype=float32),
#        array([4.45576], dtype=float32), array([-4.144898], dtype=float32),
#        array([-1.0839568], dtype=float32),
#        array([5.6501193], dtype=float32),
#        array([-17.767157], dtype=float32),
#        array([-1.1556437], dtype=float32),
#        array([7.9628563], dtype=float32),
#        array([4.8816547], dtype=float32),
#        array([3.9228783], dtype=float32),
#        array([3.3054602], dtype=float32),
#        array([7.0321317], dtype=float32),
#        array([-46.24932], dtype=float32),
#        array([7.007297], dtype=float32),
#        array([5.5283723], dtype=float32),
#        array([-1.3630197], dtype=float32),
#        array([4.9122477], dtype=float32),
#        array([-6.103383], dtype=float32),
#        array([-3.1155407], dtype=float32),
#        array([2.221205 , 2.2498953], dtype=float32),
#        array([8.712849], dtype=float32), array([6.712128], dtype=float32),
#        array([-7.393392], dtype=float32),
#        array([-2.124202], dtype=float32),
#        array([1.4994239], dtype=float32),
#        array([-3.6047518], dtype=float32),
#        array([-0.758781], dtype=float32),
#        array([-8.074523], dtype=float32),
#        array([7.4778624], dtype=float32),
#        array([9.462482], dtype=float32),
#        array([0.10593409], dtype=float32),
#        array([4.2370863], dtype=float32),
#        array([-1.513364], dtype=float32),
#        array([  9.199128,  23.44745 , -12.617351], dtype=float32),
#        array([4.8349276], dtype=float32),
#        array([-4.367705], dtype=float32),
#        array([-3.5585303], dtype=float32), array([], dtype=float32),
#        array([-9.543454], dtype=float32),
#        array([3.7809944], dtype=float32),
#        array([-5.4926515], dtype=float32),
#        array([1.8590945], dtype=float32),
#        array([15.16204 , 20.849497], dtype=float32),
#        array([5.402032], dtype=float32),
#        array([-8.973224], dtype=float32),
#        array([-2.5117354], dtype=float32),
#        array([-0.05280779], dtype=float32),
#        array([3.1098495], dtype=float32),
#        array([13.722498], dtype=float32),
#        array([-16.36713], dtype=float32),
#        array([-2.8751035], dtype=float32),
#        array([8.698366], dtype=float32), array([6.810304], dtype=float32),
#        array([5.1656895], dtype=float32),
#        array([-1.3638518], dtype=float32),
#        array([9.535013], dtype=float32), array([8.488928], dtype=float32),
#        array([14.402714], dtype=float32),
#        array([9.449241], dtype=float32), array([3.35078], dtype=float32),
#        array([-23.42292], dtype=float32),
#        array([-2.5419085], dtype=float32),
#        array([-4.638024], dtype=float32),
#        array([-19.77911], dtype=float32),
#        array([-8.433167], dtype=float32),
#        array([-1.4132997], dtype=float32)], dtype=object)

# %%
len(x)
# Out:
# 1000
