# %%
import dwong

# %%
dwong.os.chdir("/Users/wongdowling/Desktop/DQ_Dowling/ntuple_1000")
item="klong"
result=dwong.gen_wew(dwong.evt_1000[item])

# %%
n=0
for i in range(len(result[0])):
    if result[0][i]==0:
        n+=1
print(n)
# Out:
# 503

# %%
dwong.os.chdir("/Users/wongdowling/Desktop/DQ_Dowling/ntuple_1000")
item="klong"
result=dwong.gen_wew(dwong.evt_1000[item])

# %%
print(result[0][26:358])
# Out:
# [-1, -1, -1, -1, 0.9644809512196124, -1, -1, 3.969160139637567, -1, 13.182878140292583, 5.194024806764863, 3.086818751022999, 6.9818368626804945, 7.5814689851299395, -1, 2.165897108729566, 5.683365717039724, 1.4975151283124868, -1, 4.247654892776493, -1, -1, 2.0831087918442277, 4.474325440630252, -1, 3.915457045634349, 2.814571325937534, 3.3802643592263215, -1, 3.445533792134772, 1.1102230246251565e-16, 3.4232552895534676, -1, -1, 5.614333685845787, 3.632284284426324, 4.739501539003901, -1, -1, -1, 1.6014367131035456, -1, -1, -1, 5.4582431555282005, 7.161633910605463, -1, 9.568769240702585, -1, 4.183444111900201, 1.469271186238167, 4.435843792520435, -1, 0.8279431919587781, -1, -1, -1, 3.732912994017464, 7.160746722551483, 6.183133692778866, 4.030154196334912, -1, 2.442776246815354, -1, -1, -1, 4.865620479434306, -1, 4.412387453936241, 4.981450265623759, -1, 4.087082356186542, -1, -1, 3.3455839479681586, 3.184581643057362, -1, -1, 4.669320304992186, 4.429805312388916, 11.665478971383
# ...

# %%
fig = dwong.plt.figure(figsize=(10,8))
dwong.plt.hist(result[0], bins=44, range=(-2,20), histtype='step',label="photon", density=True, color="red")
dwong.plt.yscale('log')
dwong.plt.show()

# %%
a=[0]

# %%
if a==[0]:
    print("true")
# Out:
# true
