# %%
import dwong
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # First moment: Mean
# mean = dwong.np.mean(test)
#
# # Second moment: Variance
# variance = dwong.np.var(test)
#
# # Third moment: Skewness
# skewness = sp.skew(test)
#
# # Fourth moment: Kurtosis
# kurtosis = sp.kurtosis(test)

# %%
dwong.os.chdir("/Users/wongdowling/Desktop/DQ_Dowling/ntuple_1000")
types=["electron", "muon", "pi+", "pi-", "pi0", "positron", "photon", "klong"]
skew=[]
for item in types:
    skew.append(dwong.gen_skew(dwong.evt_1000[item]))  
fig = plt.figure(figsize=(10,8))
plt.hist(skew[0][0], bins=40, range=(-5,5), histtype='barstacked', label="electron", density=True, color="blue")
plt.hist(skew[6][0], bins=40, range=(-5,5), histtype='step', label="photon", density=True, color="purple")
plt.hist(skew[1][0], bins=40, range=(-5,5), histtype='step', label="muon", density=True, color="red")
plt.hist(skew[5][0], bins=40, range=(-5,5), histtype='step', label="positron", density=True, color="yellow")
plt.hist(skew[2][0], bins=40, range=(-5,5), histtype='step', label="pi+", density=True, color="orange")
plt.hist(skew[3][0], bins=40, range=(-5,5), histtype='step', label="pi-", density=True, color="black")
plt.hist(skew[4][0], bins=40, range=(-5,5), histtype='step', label="pi0", density=True, color="grey")
plt.hist(skew[6][0], bins=40, range=(-5,5), histtype='step', label="photon", density=True, color="purple")
plt.hist(skew[7][0], bins=40, range=(-5,5), histtype='step', label="klong", density=True, color="green")


plt.xlabel("Skewness(x) for the leading cluster[cm]")
plt.ylabel('Proportion of Events')
plt.yscale('log')
plt.legend()
plt.show()

fig = plt.figure(figsize=(10,8))
plt.hist(skew[0][1], bins=40, range=(-5,5), histtype='barstacked', label="electron", density=True, color="blue")
plt.hist(skew[6][1], bins=40, range=(-5,5), histtype='step', label="photon", density=True, color="purple")
plt.hist(skew[1][1], bins=40, range=(-5,5), histtype='step', label="muon", density=True, color="red")
plt.hist(skew[5][1], bins=40, range=(-5,5), histtype='step', label="positron", density=True, color="yellow")
plt.hist(skew[2][1], bins=40, range=(-5,5), histtype='step', label="pi+", density=True, color="orange")
plt.hist(skew[3][1], bins=40, range=(-5,5), histtype='step', label="pi-", density=True, color="black")
plt.hist(skew[4][1], bins=40, range=(-5,5), histtype='step', label="pi0", density=True, color="grey")
plt.hist(skew[6][1], bins=40, range=(-5,5), histtype='step', label="photon", density=True, color="purple")
plt.hist(skew[7][1], bins=40, range=(-5,5), histtype='step', label="klong", density=True, color="green")


plt.xlabel("Skewness(y) for the leading cluster[cm]")
plt.ylabel('Proportion of Events')
plt.yscale('log')
plt.legend()
plt.show()
# Out:
# /Users/wongdowling/Desktop/DQ_Dowling/electron/dwong.py:227: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skew_x.append(sp.skew(x[i]))
# /Users/wongdowling/Desktop/DQ_Dowling/electron/dwong.py:228: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skew_y.append(sp.skew(y[i]))
# /Users/wongdowling/Desktop/DQ_Dowling/electron/dwong.py:227: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skew_x.append(sp.skew(x[i]))
# ...

# %%
dwong.os.chdir("/Users/wongdowling/Desktop/DQ_Dowling/ntuple_1000")
types=["electron", "muon", "pi+", "pi-", "pi0", "positron", "photon", "klong"]
kurt=[]
for item in types:
    kurt.append(dwong.gen_kurt(dwong.evt_1000[item]))  
fig = plt.figure(figsize=(10,8))
plt.hist(kurt[0][0], bins=40, range=(-5,5), histtype='barstacked', label="electron", density=True, color="blue")
plt.hist(kurt[6][0], bins=40, range=(-5,5), histtype='step', label="photon", density=True, color="purple")
plt.hist(kurt[1][0], bins=40, range=(-5,5), histtype='step', label="muon", density=True, color="red")
plt.hist(kurt[5][0], bins=40, range=(-5,5), histtype='step', label="positron", density=True, color="yellow")
plt.hist(kurt[2][0], bins=40, range=(-5,5), histtype='step', label="pi+", density=True, color="orange")
plt.hist(kurt[3][0], bins=40, range=(-5,5), histtype='step', label="pi-", density=True, color="black")
plt.hist(kurt[4][0], bins=40, range=(-5,5), histtype='step', label="pi0", density=True, color="grey")
plt.hist(kurt[6][0], bins=40, range=(-5,5), histtype='step', label="photon", density=True, color="purple")
plt.hist(kurt[7][0], bins=40, range=(-5,5), histtype='step', label="klong", density=True, color="green")
plt.xlabel("kurtosis(x) for the leading cluster[cm]_2")
plt.ylabel('Proportion of Events')
plt.yscale('log')
plt.legend()
plt.show()

fig = plt.figure(figsize=(10,8))
plt.hist(kurt[0][1], bins=40, range=(-5,5), histtype='barstacked', label="electron", density=True, color="blue")
plt.hist(kurt[6][1], bins=40, range=(-5,5), histtype='step', label="photon", density=True, color="purple")
plt.hist(kurt[1][1], bins=40, range=(-5,5), histtype='step', label="muon", density=True, color="red")
plt.hist(kurt[5][1], bins=40, range=(-5,5), histtype='step', label="positron", density=True, color="yellow")
plt.hist(kurt[2][1], bins=40, range=(-5,5), histtype='step', label="pi+", density=True, color="orange")
plt.hist(kurt[3][1], bins=40, range=(-5,5), histtype='step', label="pi-", density=True, color="black")
plt.hist(kurt[4][1], bins=40, range=(-5,5), histtype='step', label="pi0", density=True, color="grey")
plt.hist(kurt[6][1], bins=40, range=(-5,5), histtype='step', label="photon", density=True, color="purple")
plt.hist(kurt[7][1], bins=40, range=(-5,5), histtype='step', label="klong", density=True, color="green")
plt.xlabel("Kurtosis(y) for the leading cluster[cm]_2")
plt.ylabel('Proportion of Events')
plt.yscale('log')
plt.legend()
plt.show()
# Out:
# /Users/wongdowling/Desktop/DQ_Dowling/electron/dwong.py:237: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurt_x.append(sp.skew(x[i]))
# /Users/wongdowling/Desktop/DQ_Dowling/electron/dwong.py:238: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurt_y.append(sp.skew(y[i]))
# /Users/wongdowling/Desktop/DQ_Dowling/electron/dwong.py:237: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurt_x.append(sp.skew(x[i]))
# ...
